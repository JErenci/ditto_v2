# %% [markdown]
# # DASHBOARD DEUTSCHLAND
# ### GH: https://github.com/bundesAPI/deutschlandatlas-api ###
# ### API: https://www.karto365.de/hosting/rest/services/

# %%
# import sys
# import os

# # os.path.dirname(web_functions) + '/..'
# sys.path.insert(0, os.path.dirname(os.path.dirname(web_functions)))  # or os.path.dirname(__file__) + '/..'
# # import web_functions

# %%
# sorted_table = sorted([x.lower() for x in tables])
# print(sorted_table)

# %%
tables=['Basemap_light', 'erw_mini_HA2023', 'p_nelade_r_HA2023', 'wohn_EFZH_HA2023', 'oenv_HA2023', 'bev_u18_HA2023', 'bev_ausl_HA2023', 'heiz_wohn_HA2023', 'schule_oabschl_HA2023', 'teilz_w_HA2023', 'p_selade_r_HA2023', 'ko_kasskred_HA2023', 'pendel_a_HA2023', 'preis_miet_HA2023', 'pendel_a_HA2021', 'grusi_HA2023', 'erw_vol_HA2023', 'bev_entw_HA2023', 'p_selade_f_HA2023', 'v_breitb1000_HA2023', 'v_harzt_HA2023', 'bev_dicht_HA2023', 'VG250_Verbandsgemeinden1219_Punkt', 'pfl_ambu_ZA2022', 'pendel_b_HA2023', 'sozsich_HA2021', 'beschq_m_HA2023', 'beschq_w_HA2023', 'p_elade_f_HA2022', 'alq_HA2023', 'sozsich_ZA2023', 'bev_18_65_HA2023', 'schulden_HA2023', 'elterng_v_HA2023', 'elternv_g_HA2023', 'v_breitb50_HA2023', 'teilz_m_HA2023', 'erw_mini_HA2021', 'einbr_wms', 'elade_ZA2023', 'erw_wachs_HA2023', 'st_einnkr_ZA2023', 'kinder_bg_wms', 'hh_veink_ZA2023', 'fl_suv_ZA2023', 'bev_ue65_HA2023', 'p_nelade_f_HA2023', 'wohn_leer_HA2021', 'pfl_stat_wms', 'p_ozmz_oev_r_HA2021', 'p_ozmz_miv_f_HA2021', 'erw_bip_HA2021', 'VG250_GEM1217_neu', 'fl_suv_HA2021', 'v_lte_ZA2022', 'oenv_HA2021', 'beschq_insg_HA2021', 'luftrtng_b', 'kbetr_ue3_ZA2022', 'bev_entw_ZA2022', 'erw_mini_ZA2022', 'p_poli_b', 'v_breitb50_HA2021', 'VG250_Verbandsgemeinden_1220_Punkt', 'VG250_Gemeinden1220_Punkt', 'bev_ausw_HA2022', 'bquali_oabschl_HA2022', 'fl_landw_HA2022', 'ko_kasskred_HA2022', 'kinder_bg_HA2022', 'v_lte_wms', 'bev_u18_HA2021', 'erw_minineben_ZA2022', 'wohn_MFH_ZA2022', 'bev_binw_HA2021', 'einbr_HA2021', 'bev_u18_za2022', 'bev_ue65_ZA2022', 'p_apo_f_ZA2022', 'grusi_ZA2022', 'hh_veink_ZA2022', 'bev_ausl_HA2021', 'ko_kasskred_HA2021', 'teilz_m_HA2022', 'teilz_w_HA2022', 'p_kh_sm_b', 'v_harzt_HA2022', 'schule_oabschl_HA2022', 'beschq_m_HA2022', 'p_kh_gru_b', 'beschq_w_HA2022', 'st_einnkr_HA2021', 'bev_ue65_HA2021', 'p_hbad_HA2022', 'schulden_HA2022', 'erw_vol_HA2022', 'p_elade_HA2022', 'bev_binw_HA2022', 'p_freibad_HA2022', 'straft_HA2022', 'p_markt_a', 'teilz_w_HA2021', 'VG250_Kreise1219_Punkt', 'kinder_bg_HA2021', 'kbtr_pers_HA2021', 'p_sek_2_b', 'p_markt_b', 'fl_landw_HA2021', 'kbetr_u3_HA2023', 'erw_minineben_HA2023', 'wohn_MFH_HA2023', 'elterng_v_HA2022', 'fl_wald_HA2022', 'fl_suv_HA2022', 'teilz_insg_HA2022', 'elade_HA2022', 'beschq_insg_HA2022', 'wahl_beteil_wms', 'wahl_beteil', 'wohn_EZFH_ZA2022', 'p_kh_sm_a', 'pendel_a_HA2022', 'VG250_Gemeinden1221_Punkte', 'p_elade_r_HA2022', 'fl_landw_ZA2023', 'fl_wald_ZA2023', 'kbetr_ue6_HA2023', 'kinder_bg_HA2023', 'bev_ausw_HA2023', 'bev_binw_HA2023', 'teilz_insg_HA2023', 'beschq_insg_HA2023', 'straft_HA2021', 'p_harzt_a', 'wohn_EZFH_HA2021', 'grusi_wms', 'wohn_MFH_HA2021', 'bev_dicht_ZA2021', 'pfl_stat_ZA2022', 'bquali_mabschl_HA2021', 'kbetr_u3_ZA2022', 'p_harzt_b', 'beschq_w_HA2021', 'alq_HA2021', 'p_hbad_f_HA2022', 'p_hbad_r_HA2022', 'p_freibad_r_HA2022', 'p_freibad_f_HA2022', 'bquali_mabschl_HA2022', 'heiz_wohn_HA2022', 'kbtr_pers_ZA2022', 'schule_oabschl_HA2021', 'schulden_HA2021', 'bquali_oabschl_HA2021', 'p_kh_gru_a', 'erw_wachs_ZA2022', 'luftrtng_a', 'p_sek_1_a', 'p_ozmz_oev_f_HA2021', 'pfl_geld_HA2021', 'v_breitb_ZA2021', 'p_ozmz_b', 'bev_16_65_ZA2022', 'p_ozmz_miv_r_HA2021', 'fl_wald_HA2021', 'preis_miet_HA2021', 'bquali_unifh_HA2022', 'eauto_HA2022', 'einbr_HA2022', 'VG250_Kreise_1221_Punkte', 'erw_minineben_ZA2023', 'kbtr_pers_wms', 'pfl_geld_ZA2022', 'VG250_v_lte_Grenzen', 'bev_ausl_ZA2022', 'p_grunds_a', 'VG250_LAN1217_grenzen', 'hh_veink_HA2021', 'bev_18_65_korrigiert', 'kbetr_ue6_ZA2022', 'p_apo_b', 'p_poli_a', 'bev_ausw_HA2021', 'v_lte_HA2021', 'teilz_insg_HA2021', 'preis_baul_ZA2022', 'erw_vol_HA2021', 'bquali_unifh_HA2021', 'teilz_m_HA2021', 'bev_18_65_HA2021', 'bev_entw_ZA2021', 'erw_wachs_HA2021', 'erw_bip_ZA2022', 'pfl_ambu_HA2021', 'preis_baul_wms', 'kbetr_u3_HA2021', 'preis_miet_HA2022', 'p_ozmz_a', 'beschq_m_HA2021', 'kbetr_ue3_HA2021', 'p_apo_r_ZA2022', 'bev_dicht_ZA2022', 'v_breitb1000_HA2022', 'bev_entw_wms', 'alq_HA2022', 'st_einnkr_HA2022', 'VG250_Verbandsgemeinden1218_Punkt', 'alq_HA2022_2', 'wahl_beteil_HA2022', 'p_apo_a', 'v_breitb50_HA2022', 'grusi_ZA2023', 'erw_wachs_ZA2023', 'erw_bip_ZA2023', 'erw_mini_ZA2023', 'wohn_EZFH_HA2023', 'kbtr_pers_ZA2023', 'kbetr_ue3_HA2023', 'pendel_b_HA2022', 'kbetr_ue6_HA2021', 'v_breitb1000_HA2021', 'v_harzt_HA2021', 'p_grunds_b', 'p_sek_2_a', 'pfl_stat_HA2021', 'erw_minineben_HA2021', 'elterng_v_HA2021', 'oenv_wms', 'grusi_HA2021', 'DAtlas-Loc', 'Städtenamen_Landeshauptstädte', 'VG250_Gemeinden1218_Punkt', 'p_apo_a_3857', 'DAtlas-Locator', 'VG250_Laender1218_Grenzen']

result = sum_list_tables(tables)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
# ...

# %%
dict_elems ={}
for element in sorted_table:
    elem_start = elem.split('_')[0]
    if (elem_start in
# Out:
#   Cell In[9], line 4
#     if (elem_start in
#                       ^
# SyntaxError: incomplete input

# %% [markdown]
# IMPORTS

# %%
import gdal
import web_functions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import gdal
#       2 import web_functions
#
# ModuleNotFoundError: No module named 'gdal'

# %% [markdown]
# INPUTS

# %%
# 'bev_ausl_HA_2021', 'bev_entw_ZA2022'
map_name = 'bev_ausl'#'bev_entw' 
map_type = 'HA' #'ZA' # 'HA', 'ZA'
map_year = 2021

map_name_alias= 'Bevolkerung Entwicklung [%]'

logging = True

sel_column = map_name # bev_entw_ZA2022	Gemittelte Entwicklung der Bevölkerungszahl zwischen 2015 und 2020 pro Jahr in _
path = 'gemeinden_simplify200.geojson'


first_lim = 0
second_lim = 1

first_color = 'green'
second_color = 'yellow'
third_color = 'red'

fields = ['GEN_x', 'BEZ_x',]
aliases = ['Gemeinde:', 'Bezirk:']

fields.append(map_name)
aliases.append(map_name_alias)

# %%
### Getting Dashboard Deutschland APIs ##

## NOT WORKING
# url = 'https://www.dashboard-deutschland.de/api/tile/indicators?ids=tile_1669367676459'
# dict_table = web_functions.parse_url_into_dict(url)
# dict_table


# Abrufen von Daten für ein vollständiges Dashboard
pdf_dade = web_functions.read_tables_dashboardDeutschland()
# pdf_dade

url = 'https://www.dashboard-deutschland.de/geojson/de-all.geo.json'
dict_de_geojson = web_functions.parse_url_into_dict(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 10
#       1 ### Getting Dashboard Deutschland APIs ##
#       2
#       3 ## NOT WORKING
#    (...)
#       8
#       9 # Abrufen von Daten für ein vollständiges Dashboard
# ---> 10 pdf_dade = web_functions.read_tables_dashboardDeutschland()
#      11 # pdf_dade
#      13 url = 'https://www.dashboard-deutschland.de/geojson/de-all.geo.json'
#
# NameError: name 'web_functions' is not defined

# %%
import requests
import json
import pandas as pd
import copy

# %%
import geopandas as gdf

# %%
gpd = gdf.read_file('https://www.dashboard-deutschland.de/geojson/de-all.geo.json')
gpd
# Out:
#    hc-key                    name  \
# 0    de-2                 Hamburg
# 1    de-3           Niedersachsen
# 2    de-4                  Bremen
# 3    de-5     Nordrhein-Westfalen
# 4    de-6                  Hessen
# 5    de-7         Rheinland-Pfalz
# 6    de-8       Baden-Württemberg
# 7    de-9                  Bayern
# 8   de-10                Saarland
# 9   de-11                  Berlin
# 10  de-12             Brandenburg
# 11  de-13  Mecklenburg-Vorpommern
# 12  de-14                 Sachsen
# 13  de-15          Sachsen-Anhalt
# 14  de-16               Thüringen
# 15   de-1      Schleswig-Holstein
#
#                                              geometry
# 0   MULTIPOLYGON (((578594 5953361, 575443 5948471...
# 1   MULTIPOLYGON (((354762 5941005, 351450 5940879...
# 2   MULTIPOLYGON (((468600 5896446, 470213 5895572...
# 3   MULTIPOLYGON (((477388 5819095, 479831 5816752...
# 4   MULTIPOLYGON (((534997 5719760, 540136 5719428...
# ...

# %%
# Abrufen von GeoJSON-Daten für Deutschland
response3 = requests.get('https://www.dashboard-deutschland.de/geojson/de-all.geo.json')
gdf.read_
dict_de_geojson = json.loads(response3.text)
# print(dict_de_geojson)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 # Abrufen von GeoJSON-Daten für Deutschland
#       2 response3 = requests.get('https://www.dashboard-deutschland.de/geojson/de-all.geo.json')
# ----> 3 gdf.read_
#       4 dict_de_geojson = json.loads(response3.text)
#       5 # print(dict_de_geojson)
#
# AttributeError: module 'geopandas' has no attribute 'read_'

# %%
## CHANGE CRS 
gdal_translate -of GeoJSON -a_srs EPSG:4326 input.geojson output.geojson
# Out:
#   Cell In[15], line 2
#     gdal_translate -of GeoJSON -a_srs EPSG:4326 input.geojson output.geojson
#                        ^
# SyntaxError: invalid syntax

# %%
pdf_de = pd.DataFrame.from_dict(dict_de_geojson['features'])
pdf_de
# Out:
#        type                                         properties  \
# 0   Feature              {'hc-key': 'de-2', 'name': 'Hamburg'}
# 1   Feature        {'hc-key': 'de-3', 'name': 'Niedersachsen'}
# 2   Feature               {'hc-key': 'de-4', 'name': 'Bremen'}
# 3   Feature  {'hc-key': 'de-5', 'name': 'Nordrhein-Westfalen'}
# 4   Feature               {'hc-key': 'de-6', 'name': 'Hessen'}
# 5   Feature      {'hc-key': 'de-7', 'name': 'Rheinland-Pfalz'}
# 6   Feature    {'hc-key': 'de-8', 'name': 'Baden-Württemberg'}
# 7   Feature               {'hc-key': 'de-9', 'name': 'Bayern'}
# 8   Feature            {'hc-key': 'de-10', 'name': 'Saarland'}
# 9   Feature              {'hc-key': 'de-11', 'name': 'Berlin'}
# 10  Feature         {'hc-key': 'de-12', 'name': 'Brandenburg'}
# 11  Feature  {'hc-key': 'de-13', 'name': 'Mecklenburg-Vorpo...
# 12  Feature             {'hc-key': 'de-14', 'name': 'Sachsen'}
# 13  Feature      {'hc-key': 'de-15', 'name': 'Sachsen-Anhalt'}
# ...

# %%
pdf_dex = pd.json_normalize(pdf_de['properties'])

# %%
pdf = pd.merge(pdf_de, pdf_dex, left_index=True, right_index=True)
del pdf['properties']
del pdf['type']

pdf = pdf[['hc-key','name','geometry']].sort_values(by='hc-key')
pdf
# Out:
#    hc-key                    name  \
# 15   de-1      Schleswig-Holstein
# 8   de-10                Saarland
# 9   de-11                  Berlin
# 10  de-12             Brandenburg
# 11  de-13  Mecklenburg-Vorpommern
# 12  de-14                 Sachsen
# 13  de-15          Sachsen-Anhalt
# 14  de-16               Thüringen
# 0    de-2                 Hamburg
# 1    de-3           Niedersachsen
# 2    de-4                  Bremen
# 3    de-5     Nordrhein-Westfalen
# 4    de-6                  Hessen
# 5    de-7         Rheinland-Pfalz
# 6    de-8       Baden-Württemberg
# 7    de-9                  Bayern
#
#                                              geometry
# 15  {'type': 'MultiPolygon', 'coordinates': [[[[47...
# 8   {'type': 'MultiPolygon', 'coordinates': [[[[36...
# 9   {'type': 'MultiPolygon', 'coordinates': [[[[81...
# 10  {'type': 'MultiPolygon', 'coordinates': [[[[82...
# 11  {'type': 'MultiPolygon', 'coordinates': [[[[66...
# ...

# %%
# pip install geojson
import geojson
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 # pip install geojson
# ----> 2 import geojson
#       3 import folium
#
# ModuleNotFoundError: No module named 'geojson'

# %%
import folium

# %%
fm = folium.Map()

style_function = lambda x: {
    'color' : x['properties']['color'],
    'weight' : x['properties']['stroke-width']
}

gj = folium.GeoJson(dict_de_geojson, 
                    # style_function=style_function
                   )
gj.add_to(fm)

fm

# gj = folium.GeoJson(
#     data=pdf,
#     # nan_fill_opacity=0.1,
#     style_function=style_function,
#     line_color='black',
#     highlight_function=highlight_function,
#     tooltip=tooltip
# )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# import pandas as pd
# pdf_de_geojson = pd.from_dict(dict_de_geojson)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
url = 'https://www.karto365.de/hosting/rest/services/bev_ausl_HA2021/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry'
url
# Out:
# 'https://www.karto365.de/hosting/rest/services/bev_ausl_HA2021/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry'

# %%
table = f'{map_name}_{map_type}{map_year}'
# table = 'preis_miet_HA2023'
print(f'table={table}')

geometryType='esriGeometryEnvelope&geometry'
format_answer = "json"# "html", "json", "kmz", "geojson", pbf" https://www.karto365.de/hosting/sdk/rest/index.html#/Output_formats/02ss00000078000000/
return_geometry = 'true' # 'false', 'true'

# https://machine.domain.com/webadaptor/rest/services/World_Physical_Map/MapServer?f=jsapi
url = f"https://www.karto365.de/hosting/rest/services/{table}/MapServer/0/query?f={format_answer}&where=1%3D1&outFields=*&returnGeometry={return_geometry}&geometryType={geometryType}"
url
# Out:
# table=preis_miet_HA2023
# 'https://www.karto365.de/hosting/rest/services/preis_miet_HA2023/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry'

# %%
'https://www.karto365.de/hosting/rest/services/\
bev_ausl_HA2021/MapServer/0/query?f=json\
&where=1%3D1&outFields=*&returnGeometry=true\
&geometryType=esriGeometryEnvelope&geometry'
# Out:
# 'https://www.karto365.de/hosting/rest/services/bev_ausl_HA2021/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry'

# %%
## NO (400 - Invalid or missing input parameters.)
url = 'https://www.karto365.de/hosting/rest/services/\
erw_bip_ZA2023/MapServer/1/query?f=html\
&where=1%3D1&geometryType=esriGeometryEnvelope'

url
# ## NO (404)
# 'https://www.karto365.de/hosting/rest/services/\
# erw_bip_ZA2023/MapServer/0/query?f=json\
# &where=1%3D1&outFields=*'
# Out:
# 'https://www.karto365.de/hosting/rest/services/erw_bip_ZA2023/MapServer/0/query?f=html&where=1%3D1&geometryType=esriGeometryEnvelope'

# %%
results_str = urllib.request.urlopen(url).read().decode(decoder)
# results_str
# # results_json = json.loads(results_str)
# # results_json

# %%
dict_table = web_functions.parse_url_into_dict(url)
# Out:
# good!

# %%
import web_functions

# %%
df = web_functions.convert_dict_to_pdf(dict_table)
df.head(1)
    # # df.cols = df_cols_new
    # df.columns = df.columns.str.replace('attributes.', '').str.replace('.rings','')
    # df.set_index(idx_column_name, inplace=True)
    
    # # df.sort_values(map_name).head(1)
    # df.dtypes
# Out:
#    attributes.OBJECTID  attributes.GF attributes.GEN    attributes.BEZ  \
# 0                    1              4      Flensburg  Kreisfreie Stadt
#
#    attributes.Gebietskennziffer   attributes.name  attributes.bev_ausl  \
# 0                       1001000  Flensburg, Stadt                15.21
#
#    attributes.Shape_Length  attributes.Shape_Area  \
# 0             42980.205133           4.938671e+07
#
#                                       geometry.rings
# 0  [[[1047812.9756111827, 7327520.137918544], [10...

# %%
# tag_search1 = 'ul'
# tag_search2 = 'a'
# ul_position = 1
# l_tag_search = response_rest.find_all(tag_search1)[ul_position]


# dict_tables = {}
# l_a = l_tag_search.find_all(tag_search2)
# for element in l_a:
#     dict_tables[element.text] = element['href']
# # dict_tables

# %%
# keys = sorted(dict_tables.keys())
# l_bevs = [x for x in keys if x.lower().startswith('bev_')]
# print(l_bevs)

# %%
url_bev_entw
# Out:
# 'https://www.karto365.de/hosting/rest/services/bev_entw_ZA2022/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry'

# %%
map1 = web_functions.parse_url_into_dict(url_bev_entw)
# Out:
# good!

# %%
list(map1.keys())
len(map1['features'])
# Out:
# 2000

# %%
map1

# %%
import json

# %%
data = map1['features']
idx_column_name = 'Gebietskennziffer'
col_geom = 'geometry'
# idx = 16065000

json_data = json.dumps(data)
df = pd.json_normalize(json.loads(json_data))
# df.cols = df_cols_new
df.columns = df.columns.str.replace('attributes.', '').str.replace('.rings','')
df.set_index(idx_column_name, inplace=True)

# df.sort_values(map_name).head(1)
df.dtypes
# Out:
# OBJECTID          int64
# GF                int64
# GEN              object
# BEZ              object
# name             object
# bev_entw        float64
# Shape_Length    float64
# Shape_Area      float64
# geometry         object
# dtype: object

# %%
# # table = 'bev_entw_HA2024'

# # geometryType='esriGeometryEnvelope&geometry'
# # format_answer = "json"# "html", "json", "kmz", "geojson", pbf" https://www.karto365.de/hosting/sdk/rest/index.html#/Output_formats/02ss00000078000000/
# # return_geometry = 'true' # 'false', 'true'

# # # https://machine.domain.com/webadaptor/rest/services/World_Physical_Map/MapServer?f=jsapi
# # str1 = f"https://www.karto365.de/hosting/rest/services/{table}/MapServer/0/query?f={format_answer}&where=1%3D1&outFields=*&returnGeometry={return_geometry}&geometryType={geometryType}"
# # str2 = f"https://www.karto365.de/hosting/rest/services/{table}/MapServer"

# # results = web_functions.read_url(str1, parser='json')
# len(response_rest.find('ul',2))

# l_tag_search.getString('Services')

# response_rest= requests.get(str1)


# results = soup.find_all('div', {'class': className})

# tag = results[selected_row]
# l_branches = tag.find_all('a')

# l_links = [branch.get('href') for branch in l_branches]
# l_cities = [branch.text for branch in l_branches]

# tag_row = 'h2'
# results = soup.find_all(tag_row)#, {'class': className})
# pprint.pprint(results, indent=2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['geometry_new'] = df['geometry'].astype(str)#.str.replace(',','')#replace("[","(")#.replace("]",")").replace(',','')

# %%
df['geometry_new'] = 'POLYGON '+ df['geometry_new'].str.replace(',','-').replace("[","(").replace("]",")").replace(',','')
df=df.rename(columns={"geometry_new":"geometry"})
df.drop('geometry',axis=1).head(5)
# Out:
#                    OBJECTID  GF          GEN    BEZ                    name  \
# Gebietskennziffer
# 1001000                   1   4    Flensburg  Stadt        Flensburg, Stadt
# 1002000                   2   4         Kiel  Stadt  Kiel, Landeshauptstadt
# 1003000                   3   4       Lübeck  Stadt      Lübeck, Hansestadt
# 1004000                   4   4   Neumünster  Stadt       Neumünster, Stadt
# 1051011                   5   4  Brunsbüttel  Stadt      Brunsbüttel, Stadt
#
#                    bev_entw   Shape_Length    Shape_Area
# Gebietskennziffer
# 1001000                0.93   42942.645976  4.928631e+07
# 1002000                0.02  104197.417454  1.123210e+08
# 1003000               -0.04  146500.145313  2.116850e+08
# 1004000                0.18   54387.299285  7.187184e+07
# 1051011               -0.59   41451.962294  4.989169e+07

# %%
geo_df = df

# %%
# decoder = "utf-8"
# results_str = urllib.request.urlopen(str2).read().decode(decoder)
# results_str
# # results_json = json.loads(results_str)
# # results_json

# %% [markdown]
# DE BEVOELKERUNG 2022

# %%
import pandas as pd

# %%
pd_bev = pd.read_csv('DE22c.csv')
pd_bev.head(5)
# Out:
#    Amtlicher Regionalschlüssel (ARS)                Name  \
# 0                                  0         Deutschland
# 1                                  0         Deutschland
# 2                                  0         Deutschland
# 3                                  1  Schleswig-Holstein
# 4                               1001    Flensburg, Stadt
#
#                            Regionalebene Bevölkerung Zensus 2022*  \
# 0        Bund (mit Deutschen im Ausland)               82 719 540
# 1                    Deutsche im Ausland                    8 258
# 2        Bund (ohne Deutsche im Ausland)               82 711 282
# 3                                   Land                2 927 542
# 4  Stadtkreis/kreisfreie Stadt/Landkreis                   95 015
#
#   Bevölkerung Bevölkerungsfortschreibung zum 30.06.2022 auf Basis Zensus 2011**  \
# 0                                                  –
# 1                                                  –
# ...

# %%
pd_bev=pd_bev.rename(columns={"Amtlicher Regionalschlüssel (ARS)":"Gebietskennziffer"})
pd_bev.head(5)
# Out:
#    Gebietskennziffer                Name  \
# 0                  0         Deutschland
# 1                  0         Deutschland
# 2                  0         Deutschland
# 3                  1  Schleswig-Holstein
# 4               1001    Flensburg, Stadt
#
#                            Regionalebene Bevölkerung Zensus 2022*  \
# 0        Bund (mit Deutschen im Ausland)               82 719 540
# 1                    Deutsche im Ausland                    8 258
# 2        Bund (ohne Deutsche im Ausland)               82 711 282
# 3                                   Land                2 927 542
# 4  Stadtkreis/kreisfreie Stadt/Landkreis                   95 015
#
#   Bevölkerung Bevölkerungsfortschreibung zum 30.06.2022 auf Basis Zensus 2011**  \
# 0                                                  –
# 1                                                  –
# 2                                         84 079 811
# 3                                          2 946 021
# ...

# %%
pd_bev.dtypes
# Out:
# Gebietskennziffer                                                                                             int64
# Name                                                                                                         object
# Regionalebene                                                                                                object
# Bevölkerung Zensus 2022*                                                                                     object
# Bevölkerung Bevölkerungsfortschreibung zum 30.06.2022 auf Basis Zensus 2011**                                object
# Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** absolut       object
# Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** prozentual    object
# dtype: object

# %%
pd_bev.set_index('Gebietskennziffer', inplace=True)
pd_bev
# Out:
#                                      Name  \
# Gebietskennziffer
# 0                             Deutschland
# 0                             Deutschland
# 0                             Deutschland
# 1                      Schleswig-Holstein
# 1001                     Flensburg, Stadt
# ...                                   ...
# 160775051023       Langenleuba-Niederhain
# 160775051036                       Nobitz
# 160775052                 Schmölln, Stadt
# 160775052003                   Dobitschen
# 160775052043              Schmölln, Stadt
#
#                                            Regionalebene  \
# Gebietskennziffer
# 0                        Bund (mit Deutschen im Ausland)
# 0                                    Deutsche im Ausland
# 0                        Bund (ohne Deutsche im Ausland)
# 1                                                   Land
# 1001               Stadtkreis/kreisfreie Stadt/Landkreis
# ...                                                  ...
# ...

# %% [markdown]
# TESTS

# %%
pd_bev.loc[[160775051023]]
# Out:
#                                      Name Regionalebene  \
# Gebietskennziffer
# 160775051023       Langenleuba-Niederhain      Gemeinde
#
#                   Bevölkerung Zensus 2022*  \
# Gebietskennziffer
# 160775051023                         1 722
#
#                   Bevölkerung Bevölkerungsfortschreibung zum 30.06.2022 auf Basis Zensus 2011**  \
# Gebietskennziffer
# 160775051023                                                   1 731
#
#                   Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** absolut  \
# Gebietskennziffer
# 160775051023                                                    -  9
#
#                   Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** prozentual
# Gebietskennziffer
# 160775051023                                                  -0.520

# %%
pd_bev.loc[[1001000]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 pd_bev.loc[[1001000]]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %%
geo_df.iloc[[0]]
# Out:
#                    OBJECTID  GF        GEN    BEZ              name  bev_entw  \
# Gebietskennziffer
# 1001000                   1   4  Flensburg  Stadt  Flensburg, Stadt      0.93
#
#                    Shape_Length    Shape_Area  \
# Gebietskennziffer
# 1001000            42942.645976  4.928631e+07
#
#                                                             geometry  \
# Gebietskennziffer
# 1001000            [[[1047812.9755482934, 7327520.137946451], [10...
#
#                                                             geometry
# Gebietskennziffer
# 1001000            POLYGON [[[1047812.9755482934- 7327520.1379464...

# %%
table = 'bev_ausl_HA_2021'
map_name = 'bev_ausl' 
# 'bev_ausl_HA_2021', 'bev_entw_ZA2022'
map_type = 'ZA' # 'HA', 'ZA'
map_year = 2022
# table = f'{map_name}_{map_type}{map_year}'

geometryType='esriGeometryEnvelope&geometry'
format_answer = "json"# "html", "json", "kmz", "geojson", pbf" https://www.karto365.de/hosting/sdk/rest/index.html#/Output_formats/02ss00000078000000/
return_geometry = 'true' # 'false', 'true'

# https://machine.domain.com/webadaptor/rest/services/World_Physical_Map/MapServer?f=jsapi
str1 = f"https://www.karto365.de/hosting/rest/services/{table}/MapServer/0/query?f={format_answer}&where=1%3D1&outFields=*&returnGeometry={return_geometry}&geometryType={geometryType}"
print(f'str1={str1}')

map1 = web_functions.parse_url_into_dict(str1)
# map2 = parse_url_into_dict(str2)

print(list(map1.keys()))
print(len(map1['features']))
# Out:
# str1=https://www.karto365.de/hosting/rest/services/bev_ausl_HA_2021/MapServer/0/query?f=json&where=1%3D1&outFields=*&returnGeometry=true&geometryType=esriGeometryEnvelope&geometry
# good!
# ['error']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 20
#      17 # map2 = parse_url_into_dict(str2)
#      19 print(list(map1.keys()))
# ---> 20 print(len(map1['features']))
#
# KeyError: 'features'

# %%
map1 = web_functions.parse_url_into_dict(url_bev_entw)

# %%
geo_df.loc[[1001000]]
# Out:
#                    OBJECTID  GF        GEN    BEZ              name  bev_entw  \
# Gebietskennziffer
# 1001000                   1   4  Flensburg  Stadt  Flensburg, Stadt      0.93
#
#                    Shape_Length    Shape_Area  \
# Gebietskennziffer
# 1001000            42942.645976  4.928631e+07
#
#                                                             geometry  \
# Gebietskennziffer
# 1001000            [[[1047812.9755482934, 7327520.137946451], [10...
#
#                                                             geometry
# Gebietskennziffer
# 1001000            POLYGON [[[1047812.9755482934- 7327520.1379464...

# %% [markdown]
# MERGE DFs

# %%
geo_df#.drop('geometry',axis=1).head(1)
# Out:
#                    OBJECTID  GF           GEN       BEZ  \
# Gebietskennziffer
# 1001000                   1   4     Flensburg     Stadt
# 1002000                   2   4          Kiel     Stadt
# 1003000                   3   4        Lübeck     Stadt
# 1004000                   4   4    Neumünster     Stadt
# 1051011                   5   4   Brunsbüttel     Stadt
# ...                     ...  ..           ...       ...
# 3458014                1996   4  Wildeshausen     Stadt
# 3458001                1997   4       Beckeln  Gemeinde
# 3458002                1998   4      Colnrade  Gemeinde
# 3458004                1999   4        Dünsen  Gemeinde
# 3458006                2000   4  Groß Ippener  Gemeinde
#
#                                      name  bev_entw   Shape_Length  \
# Gebietskennziffer
# 1001000                  Flensburg, Stadt      0.93   42942.645976
# 1002000            Kiel, Landeshauptstadt      0.02  104197.417454
# ...

# %%
pdf_kreis_data = pd.merge(geo_df,pd_bev, left_index=True, right_index=True)
pdf_kreis_data.head(5)
# Out:
# Empty DataFrame
# Columns: [OBJECTID, GF, GEN, BEZ, name, bev_entw, Shape_Length, Shape_Area, geometry, geometry, Name, Regionalebene, Bevölkerung Zensus 2022*, Bevölkerung Bevölkerungsfortschreibung zum 30.06.2022 auf Basis Zensus 2011**, Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** absolut, Veränderung Zensus 2022 zur Bevölkerungsfortschreibung zum 30.06.2022  auf Basis Zensus 2011** prozentual]
# Index: []

# %%
geo_df.iloc['1001000']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 geo_df.iloc['1001000']
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# -> 1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
#
# ...

# %%
pd_bev[[160775051023]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 pd_bev[[160775051023]]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...
