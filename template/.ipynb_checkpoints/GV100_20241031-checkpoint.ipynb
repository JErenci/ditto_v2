# %%
import pandas as pd

# %% [markdown]
# # 1. DEFINITIONS [SATZARTEN]

# %% [markdown]
# ## SATZART-10 [Landdaten]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 2

# %%
Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
EF-Nr    von-bis Anzahl  Allg.  Intern    
######   #######     ##     #      ###   ###########
EF1        1-  2      2     C      ALN   Satzart 10
EF2        3- 10      8                  Gebietstand
 EF2U1     3-  6      4     C      ALN     Jahr
 EF2U2     7-  8      2     C      ALN     Monat
 EF2U3     9- 10      2     C      ALN     Tag
EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
 EF3U1    11- 12      2     C      ALN      Land
 EF3U2    13          1     c      ALN      Leer
 EF3U3    14- 15      2     C      ALN      Leer
 EF3U4    16- 18      3     C      ALN      Leer
EF4       19- 22      4     C      ALN     Leer
EF5       23- 72     50     C      ALN     Landbezeichnung
EF6       73-122     50     C      ALN     Sitz der Landesregierung
EF7      123-128      6                    Schlüsselfelder
 EF7U1   123-124      2     C      ALN      Leer
 EF7U2   125-126      2     C      ALN      Leer
 EF7U3   127-128      2     C      ALN      Leer
EF8      129-200     72     C      ALN     Leer
EF9      201-220     20     C      ALN     Frei für landesinterne Angaben
# Out:
#   Cell In[31], line 1
#     Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## SATZART-20 [Regierungsbezirksdaten]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 3

# %% [markdown]
# Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
# EF-Nr    von-bis Anzahl  Allg.  Intern
# ######   #######     ##     #      ###   ###########
# EF1        1-  2      2     C      ALN   Satzart 20
# EF2        3- 10      8                  Gebietstand
#  EF2U1     3-  6      4     C      ALN     Jahr
#  EF2U2     7-  8      2     C      ALN     Monat
#  EF2U3     9- 10      2     C      ALN     Tag
# EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
#  EF3U1    11- 12      2     C      ALN      Land
#  EF3U2    13          1     c      ALN      Regierungsbezirk
#  EF3U3    14- 15      2     C      ALN      Leer
#  EF3U4    16- 18      3     C      ALN      Leer
# EF4       19- 22      4     C      ALN     Leer
# EF5       23- 72     50     C      ALN     Regierungsbezirksbezeichnung
# EF6       73-122     50     C      ALN     Sitz der Regierungsbezirks
# EF7      123-128      6                    Schlüsselfelder
#  EF7U1   123-124      2     C      ALN      Leer
#  EF7U2   125-126      2     C      ALN      Leer
#  EF7U3   127-128      2     C      ALN      Leer
# EF8      129-200     72     C      ALN     Leer
# EF9      201-220     20     C      ALN     Frei für landesinterne Angaben

# %% [markdown]
# ## SATZART-30 [Regionsdaten (nur BaWü)]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 4

# %% [markdown]
# Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
# EF-Nr    von-bis Anzahl  Allg.  Intern
# ######   #######     ##     #      ###   ###########
# EF1        1-  2      2     C      ALN   Satzart 30
# EF2        3- 10      8                  Gebietstand
#  EF2U1     3-  6      4     C      ALN     Jahr
#  EF2U2     7-  8      2     C      ALN     Monat
#  EF2U3     9- 10      2     C      ALN     Tag
# EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
#  EF3U1    11- 12      2     C      ALN      Land
#  EF3U2    13          1     c      ALN      Regierungsbezirk
#  EF3U3    14- 15      2     C      ALN      Region (x@). Zur Abbildung der Region wird lediglich Satzstelle 14 benötigt
#  EF3U4    16- 18      3     C      ALN      Leer
# EF4       19- 22      4     C      ALN     Leer
# EF5       23- 72     50     C      ALN     Regionsbezeichnung
# EF6       73-122     50     C      ALN     Sitz der Region
# EF7      123-128      6                    Schlüsselfelder
#  EF7U1   123-124      2     C      ALN      Leer
#  EF7U2   125-126      2     C      ALN      Leer
#  EF7U3   127-128      2     C      ALN      Leer
# EF8      129-200     72     C      ALN     Leer
# EF9      201-220     20     C      ALN     Frei für landesinterne Angaben

# %% [markdown]
# ## SATZART-40 [Kreisdaten (1) -> administrative Gebietseinheiten]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 5

# %% [markdown]
# Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
# EF-Nr    von-bis Anzahl  Allg.  Intern
# ######   #######     ##     #      ###   ###########
# EF1        1-  2      2     C      ALN   Satzart 40
# EF2        3- 10      8                  Gebietstand
#  EF2U1     3-  6      4     C      ALN     Jahr
#  EF2U2     7-  8      2     C      ALN     Monat
#  EF2U3     9- 10      2     C      ALN     Tag
# EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
#  EF3U1    11- 12      2     C      ALN      Land
#  EF3U2    13          1     c      ALN      Regierungsbezirk
#  EF3U3    14- 15      2     C      ALN      Kreis
#  EF3U4    16- 18      3     C      ALN      Leer
# EF4       19- 22      4     C      ALN     Leer
# EF5       23- 72     50     C      ALN     Kreisbezeichnung
# EF6       73-122     50     C      ALN     Sitz der Kreisverwaltung
# EF7      123-128      6                    Schlüsselfelder
#  EF7U1   123-124      2     C      ALN      Textkennzeichen
#                                             41 - Kreisfreie Stadt
#                                             42 - Stadtkreis
#                                             43 - Kreis
#                                             44 - Landkreis
#                                             45 - Regionalverband
#  EF7U2   125-126      2     C      ALN      Leer
#  EF7U3   127-128      2     C      ALN      Leer
# EF8      129-200     72     C      ALN     Leer
# EF9      201-220     20     C      ALN     Frei für landesinterne Angaben

# %% [markdown]
# ## SATZART-50 [Gemeindeverbandsdaten]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 6

# %% [markdown]
# Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
# EF-Nr    von-bis Anzahl  Allg.  Intern
# ######   #######     ##     #      ###   ###########
# EF1        1-  2      2     C      ALN   Satzart 50
# EF2        3- 10      8                  Gebietstand
#  EF2U1     3-  6      4     C      ALN     Jahr
#  EF2U2     7-  8      2     C      ALN     Monat
#  EF2U3     9- 10      2     C      ALN     Tag
# EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
#  EF3U1    11- 12      2     C      ALN      Land
#  EF3U2    13          1     c      ALN      Regierungsbezirk
#  EF3U3    14- 15      2     C      ALN      Region (x@). Zur Abbildung der Region wird lediglich Satzstelle 14 benötigt
#  EF3U4    16- 18      3     C      ALN      Kreis
# EF4       19- 22      4     C      ALN      Leer
# EF5       23- 72     50     C      ALN     Gemeindeverband
# EF6       73-122     50     C      ALN     Sitz der Gemeindeverbandes
# EF7      123-128      6                    Schlüsselfelder
#  EF7U1   123-124      2     C      ALN      Textkennzeichen
#                                             50 - verbandsfreie Gemeinde
#                                             51 - Amt
#                                             52 - Samtgemeinde
#                                             53 - Verbandsgemeinde
#                                             54 - Verwaltungsgemeinschaft
#                                             55 - Kirchspielslandgemeinde
#                                             56 - Verwaltungsverband
#                                             57 - VG Trägermodell
#                                             58 - Erfüllende Gemeinde
#  EF7U2   125-126      2     C      ALN      Leer
#  EF7U3   127-128      2     C      ALN      Leer
# EF8      129-200     72     C      ALN     Leer
# EF9      201-220     20     C      ALN     Frei für landesinterne Angaben

# %% [markdown]
# ## SATZART-60 [Gemeindedaten (1) -> administrative Gebietseinheiten]
# ```Datensatzbeschreibung_GV100AD.pdf```, page 7

# %% [markdown]
# Feldbez.  Satzstellen     Feldformat      Inhalt/Bemerkungen
# EF-Nr    von-bis Anzahl  Allg.  Intern
# ######   #######     ##     #      ###   ###########
# EF1        1-  2      2     C      ALN   Satzart 60
# EF2        3- 10      8                  Gebietstand
#  EF2U1     3-  6      4     C      ALN     Jahr
#  EF2U2     7-  8      2     C      ALN     Monat
#  EF2U3     9- 10      2     C      ALN     Tag
# EF3       11- 18      8     C      ALN     Amtlicher Regionalschlüssel
#  EF3U1    11- 12      2     C      ALN      Land
#  EF3U2    13          1     c      ALN      Regierungsbezirk
#  EF3U3    14- 15      2     C      ALN      Kreis
#  EF3U4    16- 18      3     C      ALN      Gemeinde
# EF4       19- 22      4     C      ALN     Leer
# EF5       23- 72     50     C      ALN     Gemeindeverband
# EF6       73-122     50     C      ALN     Leer
# EF7      123-128      6                    Schlüsselfelder
#  EF7U1   123-124      2     C      ALN      Textkennzeichen
#                                             60 - Markt
#                                             61 - Kreisfreie Stadt
#                                             62 - Stadtkreis
#                                             63 - Stadt
#                                             64 - Kreisangehörige Gemeinde
#                                             65 - gemeindefreies Gebiet, bewohnt
#                                             66 - gemeindefreies Gebiet, unbewohnt
#                                             67 - große Kreisstadt
#  EF7U2   125-126      2     C      ALN      Leer
#  EF7U3   127-128      2     C      ALN      Leer
# EF8      129-139     11     C NOV11K00     Fläche in ha
# EF9      140-150     11     C NOV11K00     Bevölkerung, insgesamt
# EF10     151-161     11     C NOV11K00     Bevölkerung, männlich
# EF11     162-165      4     C      ALN     Leer
# EF12     166-175     10                    Neue Postleitzahl
#  EF12U1  166-170      5     C      ALN      PLZ der Gemeinde (bei mehreren Postleitzahlen - PLZ des Verwaltungssitzes)
#  EF12U2  171-175      6     C      ALN      Kennzeichnung, ob PLZ eindeutig (leer = Gemeinde hat nur eine PLZ, sonst = Gemeinde hat mehrere PLZ)
# EF13     176-177      2     C      ALN     LEER
# EF14     178-181      4     C      ALN     Finanzamtsbezirk
# EF15     182-185      5                    Gerichtsbarkeit
#  EF15U1  182-183      2     C      ALN      Oberlandesgerichtsbezirk
#  EF15U2  184          1     C      ALN      Landgerichtsbezirk
#  EF15U3  185          1     C      ALN      Amtsgerichtsbezirk
# EF16     186-190      5     C      ALN     Arbeitsagenturbezirk
# EF17     191-196      6                    Bundestagswahlkreise
#  EF17U1  191-193      3     C      ALN      Bundestagswahlkreis
#  EF17U2  194-196      3     C      ALN      Bundestagswahlkreis
# EF18     197-200      2     C      ALN    Leer
# EF19     201-220     20     C      ALN    Frei für landesinterne Angaben

# %% [markdown]
# # 2. PROCESSING [PARSING ```GV_100AD_DDMMYYYY.txt```]
#
# #### SATZART-10 [Landdaten]
# #### SATZART-20 [Regierungsbezirksdaten]
# #### SATZART-30 [Regionsdaten (nur BaWü)]
# #### SATZART-40 [Kreisdaten (1) -> administrative Gebietseinheiten]
# #### SATZART-50 [Gemeindeverbandsdaten]
# #### SATZART-60 [Gemeindedaten (1) -> administrative Gebietseinheiten]

# %% [markdown]
# ## 2.1. Satzarten [10,20,30,40,50]

# %% [markdown]
# ### 2.1.1. PARSE FILE ```df```

# %%
filename = 'GV100AD_31102024'

widths=[
     2, # EF1,   1-  2
     8, # EF2,   3- 10
     8, # EF3,  11- 18
     4, # EF4,  19- 22
    50, # EF5,  23- 72
    50, # EF6,  73-122
     6, # EF7, 123-128
    72, # EF8, 129-200
    20, # EF9, 200-220
]

col_names = [
    'EF1_Satzart',
    'EF2_Gebietstand',
    'EF3_ARS',
    'EF4_Verband',
    'EF5_Verbandsbezeichnung',
    'EF6_Sitz_des_Verbandes',
    'EF7_Schlüsselfelder',
    'EF8_Leer',
    'EF9_Frei für landesinterne Angaben',
]

# %%
path_GV100_read= f'GV_GemeindeVerzeichnis//{filename}.txt'
path_GV100_save= f'GV_GemeindeVerzeichnis//{filename}_df.csv'
path_GV100_read
# Out:
# 'GV_GemeindeVerzeichnis//GV100AD_31102024.txt'

# %%
import f_gemeinde_verzeichnis

# %%
df = f_gemeinde_verzeichnis.parse_GV100(path_read=path_GV100_read, widths=widths, col_names=col_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = f_gemeinde_verzeichnis.parse_GV100(path_read=path_GV100_read, widths=widths, col_names=col_names)
#
# File ~\PycharmProjects\ditto_v2\template\f_gemeinde_verzeichnis.py:28, in parse_GV100(path_read, widths, col_names, path_save, is_logging)
#      24 df[col_BL_number] = df[col_BL_number].astype('int')
#      25 # df['EF4_Verband'] = df['EF4_Verband'].fillna(0).astype('int')
#      26
#      27 ## ADDING column 'BL_name'
# ---> 28 df[col_BL_name] = df[col_BL_number].map(f_deutschland_2022.dict_id_bundeslaender)
#      30 if is_logging:
#      31     print(f'df.shape={df.shape}')
#
# NameError: name 'f_deutschland_2022' is not defined

# %%
df = pd.read_fwf(
    filepath_or_buffer= 'GV_GemeindeVerzeichnis/GV100AD_31102024.txt', 
    widths=widths, 
    header=None,
    names=col_names,
    dtype={'EF3_ARS': str}
)  # Specify column widths

df.replace({
    'Ã¼': 'ü',
    'Ã¶': 'ö',
    'ÃŸ': 'ß',
    'Ã¤': 'ä',
}, inplace=True)

## ADDING column 'BL_nr' and set column type to int
df[col_BL_number] = df['EF3_ARS'].str.slice(0, 2)
df[col_BL_number] = df[col_BL_number].astype('int')
# df['EF4_Verband'] = df['EF4_Verband'].fillna(0).astype('int')

## ADDING column 'BL_name'
df[col_BL_name] = df[col_BL_number].map(f_deutschland_2022.dict_id_bundeslaender)

print(f'df.shape={df.shape}')

if is_file_saved:
    df.to_csv(path_file_saved)

df
# Out:
# df.shape=(16012, 11)
#        EF1_Satzart  EF2_Gebietstand   EF3_ARS  EF4_Verband  \
# 0               10         20241031        01          NaN
# 1               40         20241031     01001          NaN
# 2               50         20241031     01001          0.0
# 3               60         20241031  01001000          0.0
# 4               40         20241031     01002          NaN
# ...            ...              ...       ...          ...
# 16007           60         20241031  16077044       5005.0
# 16008           60         20241031  16077047       5009.0
# 16009           60         20241031  16077048       5004.0
# 16010           60         20241031  16077049       5009.0
# 16011           60         20241031  16077052       5004.0
#
#       EF5_Verbandsbezeichnung EF6_Sitz_des_Verbandes  EF7_Schlüsselfelder  \
# 0          Schleswig-Holstein                   Kiel                  NaN
# 1            Flensburg, Stadt              Flensburg                 41.0
# ...

# %% [markdown]
# ### 2.1.2. SUM FILE ```df_adm_sum```

# %%
df_adm_sum = df.groupby([col_BL_name])['EF1_Satzart'].count().to_frame()
print(f'sum(df_adm_sum)= {df_adm_sum.sum()}')
df_adm_sum
# Out:
# sum(df_adm_sum)= EF1_Satzart    16012
# dtype: int64
#                         EF1_Satzart
# BL_name
# Baden-Württemberg              1626
# Bayern                         3887
# Berlin                            4
# Brandenburg                     625
# Bremen                            7
# Hamburg                           4
# Hessen                          880
# Mecklenburg-Vorpommern          851
# Niedersachsen                  1442
# Nordrhein-Westfalen             851
# Rheinland-Pfalz                2513
# Saarland                        113
# Sachsen                         744
# Sachsen-Anhalt                  355
# Schleswig-Holstein             1293
# Thüringen                       817

# %% [markdown]
# ## 2.2. Satzarten [60]

# %% [markdown]
# ### 2.2.1. PARSE FILE in ```df_60```

# %%
import f_gemeinde_verzeichnis

# %%
width_60 = [
    11, #11 Fläche in ha
    11, #11 Bevölkerung, insgesamt
    11, #11 Bevölkerung, männlich
    4,  #4  Leer
    10, #10 Neue Postleitzahl
    2,  #2  Leer
    4,  #4  Finanzamtsbezirk
    5,  #4  Gerichtsbarkeit
    5,  #5  Arbeitsagenturbezirk
    6,  #6  Bundestagswahlkreise
    4   #4  Leer
]
df_60 = parse_60(df=df, width_60=width_60)
# Out:
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[col_REGBEZ_number] = df_60['EF3_ARS'].str.slice(2, 3).astype('int')
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[col_KREIS_number] = df_60['EF3_ARS'].str.slice(3, 5).astype('int')
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:47: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## 2.2. SUMMARISE FILE for [Gemeinde, Bevölkerung,Fläche] in ```df_sum```
# - SATZARTEN (```df_adm_sum```)

# %%
import f_gemeinde_verzeichnis

# %%
width_60 = [
    11, #11 Fläche in ha
    11, #11 Bevölkerung, insgesamt
    11, #11 Bevölkerung, männlich
    4,  #4  Leer
    10, #10 Neue Postleitzahl
    2,  #2  Leer
    4,  #4  Finanzamtsbezirk
    4,  #4  Gerichtsbarkeit
    5,  #5  Arbeitsagenturbezirk
    6,  #6  Bundestagswahlkreise
    4   #4  Leer
]
df_60 = parse_60(df=df, width_60=width_60)

df_ade1 = process_sa60(df=df_60, ADE_level=1)
print(f'shape(df_ade1)=[{df_ade1.shape}]')
# df_ade1

df_ade2 = process_sa60(df=df_60, ADE_level=2)
print(f'shape(df_ade2)=[{df_ade2.shape}]')
df_ade3 = process_sa60(df=df_60, ADE_level=3)
print(f'shape(df_ade3)=[{df_ade3.shape}]')
df_ade4 = process_sa60(df=df_60, ADE_level=4)
print(f'shape(df_ade4)=[{df_ade4.shape}]')
df_ade5 = process_sa60(df=df_60, ADE_level=5)
print(f'shape(df_ade5)=[{df_ade5.shape}]')
df_ade6 = process_sa60(df=df_60, ADE_level=6)
print(f'shape(df_ade6)=[{df_ade6.shape}]')
# Out:
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[col_REGBEZ_number] = df_60['EF3_ARS'].str.slice(2, 3).astype('int')
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[col_KREIS_number] = df_60['EF3_ARS'].str.slice(3, 5).astype('int')
# C:\Users\gujua\AppData\Local\Temp\ipykernel_15356\2471914544.py:47: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## TESTS

# %% [markdown]
# ### BREMEN (04)

# %%
## BREMEN
l_cols = [
    'Fläche in ha',
    'Bevölkerung, insgesamt',
    'Bevölkerung, männlich',
    'Neue Postleitzahl',
    'Finanzamtsbezirk','Gerichtsbarkeit','Arbeitsagenturbezirk',
    'Bundestagswahlkreise'
]
df_ade4[df_ade4['ADE2']=='04'][l_cols]
# Out:
#    Fläche in ha                   Bevölkerung, insgesamt                      \
#             sum   median     mean                    sum    median      mean
# 61        31820  31820.0  31820.0                 577026  577026.0  577026.0
# 62        10141  10141.0  10141.0                 114677  114677.0  114677.0
#
#    Bevölkerung, männlich                     Neue Postleitzahl                \
#                      sum    median      mean           nunique        unique
# 61                285270  285270.0  285270.0                 1  [28195*****]
# 62                 56716   56716.0   56716.0                 1  [27576*****]
#
#    Finanzamtsbezirk         Gerichtsbarkeit         Arbeitsagenturbezirk  \
#             nunique  unique         nunique  unique              nunique
# 61                1  [2471]               1  [1101]                    1
# 62                1  [2475]               1  [1102]                    1
#
#             Bundestagswahlkreise
# ...

# %%
# BREMEN
df_60[df_60['BL_nr']==4]['EF8_Leer'].values#[l_cols]
# 000000318200000057702600000285270    28195*****  2471110121401054055
  # 00000031820, 00000577026, 00000285270,    ,28195*****,  ,2471,1101,21401,054055
# 000000101410000011467700000056716    27576*****  2475110221419055
  # 00000010141, 00000114677, 00000056716,    ,27576*****,  ,2475,1102,21419,055

# 11, #11 Fläche in ha            [00000031820, 00000010141] YES
# 11, #11 Bevölkerung, insgesamt  [00000577026, 00000114677] YES
# 11, #11 Bevölkerung, männlich   [00000285270, 00000056716] YES
# 4,  #4 Leer                     [     '    ',      '    '] YES
# 10, #10 Neue Postleitzahl       [ 28195*****,  27576*****] YES
# 2,  #2 Leer                     [       '  ',        '  '] YES
# 4,  #4 Finanzamtsbezirk         [       2471,        2475] YES
# 5,  #4 Gerichtsbarkeit          [       1101,        1102] YES
# 5,  #5 Arbeitsagenturbezirk     [      21401,       21419] YES
# 6,  #6 Bundestagswahlkreise     [     054055,      055   ] YES
# 4   # Leer
# Out:
# array(['000000318200000057702600000285270    28195*****  2471110121401054055',
#        '000000101410000011467700000056716    27576*****  2475110221419055'],
#       dtype=object)

# %% [markdown]
# ### HAMBURG (02)

# %%
## HAMBURG
l_cols = [
    'Fläche in ha',
    'Bevölkerung, insgesamt',
    'Bevölkerung, männlich',
    'Neue Postleitzahl',
    'Finanzamtsbezirk','Gerichtsbarkeit','Arbeitsagenturbezirk',
    'Bundestagswahlkreise'
]
df_ade4[df_ade4['ADE2']=='02'][l_cols]
# Out:
#    Fläche in ha                   Bevölkerung, insgesamt             \
#             sum   median     mean                    sum     median
# 15        75509  75509.0  75509.0                1910160  1910160.0
#
#               Bevölkerung, männlich                     Neue Postleitzahl  \
#          mean                   sum    median      mean           nunique
# 15  1910160.0                936740  936740.0  936740.0                 1
#
#                  Finanzamtsbezirk         Gerichtsbarkeit          \
#           unique          nunique  unique         nunique  unique
# 15  [20038*****]                1  [2202]               1  [1100]
#
#    Arbeitsagenturbezirk          Bundestagswahlkreise
#                 nunique   unique              nunique   unique
# 15                    1  [12301]                    1  [18023]

# %%
# HAMBURG
df_60[df_60['BL_nr']==2]['EF8_Leer'].values
# 000000755090000191016000000936740    20038*****  2202110012301018023
  # 00000075509, 00001910160, 00000936740,    , 20038*****,   , 2202, 1100, 12301, 018023
# Out:
# array(['000000755090000191016000000936740    20038*****  2202110012301018023'],
#       dtype=object)

# %% [markdown]
# # SAVE DFs

# %%
df_ade1.head(1)
# df_ade1.to_csv('df_ade1.csv')
# Out:
#             ARS BL_name ADE2_LAND        BEZ_NR        KREIS_NR         \
#                              mean  count   mean  count     mean  count
# 0  000000000000      60      7.96  10959   2.23  10959    53.51  10959
#
#   EF4_Verband         ... Neue Postleitzahl  \
#          mean  count  ...           nunique
# 0     3812.86  10959  ...              6678
#
#                                                      Finanzamtsbezirk  \
#                                               unique          nunique
# 0  [24937*****, 24103*****, 23539*****, 24534****...              460
#
#                                                      Gerichtsbarkeit  \
#                                               unique         nunique
# 0  [2115, 2119, 2122, 2124, 2123, 2116, 2127, 212...             391
#
#                                                      Arbeitsagenturbezirk  \
#                                               unique              nunique
# ...

# %%
df_ade2.head()
# df_ade2.to_csv('df_ade2.csv')
# Out:
#             ARS              BL_name ADE2 ADE2_LAND       BEZ_NR        \
#                                                mean count   mean count
# 0  010000000000   Schleswig-Holstein   01       1.0  1106   0.00  1106
# 1  020000000000              Hamburg   02       2.0     1   0.00     1
# 2  030000000000        Niedersachsen   03       3.0   964   2.68   964
# 3  040000000000               Bremen   04       4.0     2   0.00     2
# 4  050000000000  Nordrhein-Westfalen   05       5.0   396   5.03   396
#
#   KREIS_NR       EF4_Verband  ... Neue Postleitzahl  \
#       mean count        mean  ...           nunique
# 0    56.50  1106     5075.98  ...               467
# 1     0.00     1        0.00  ...                 1
# 2    54.80   964     3895.15  ...               674
# 3    11.50     2        0.00  ...                 2
# 4    61.66   396       26.45  ...               394
#
#                                                      Finanzamtsbezirk  \
# ...

# %%
df_ade3.head()
# df_ade3.to_csv('df_ade3.csv')
# Out:
#             ARS             BL_name ADE2 ADE3 ADE2_LAND       BEZ_NR        \
#                                                    mean count   mean count
# 0  010000000000  Schleswig-Holstein   01    0       1.0  1106    0.0  1106
# 1  020000000000             Hamburg   02    0       2.0     1    0.0     1
# 2  031000000000       Niedersachsen   03    1       3.0   175    1.0   175
# 3  032000000000       Niedersachsen   03    2       3.0   207    2.0   207
# 4  033000000000       Niedersachsen   03    3       3.0   333    3.0   333
#
#   KREIS_NR        ... Neue Postleitzahl  \
#       mean count  ...           nunique
# 0    56.50  1106  ...               467
# 1     0.00     1  ...                 1
# 2    54.47   175  ...               127
# 3    53.04   207  ...               156
# 4    55.81   333  ...               228
#
#                                                      Finanzamtsbezirk  \
#                                               unique          nunique
# ...

# %%
# df_ade4.to_csv('df_ade4.csv')
df_ade4#.head()
# Out:
#               ARS             BL_name ADE2 ADE3 ADE4 ADE2_LAND       BEZ_NR  \
#                                                           mean count   mean
# 0    010010000000  Schleswig-Holstein   01    0   01       1.0     1    0.0
# 1    010020000000  Schleswig-Holstein   01    0   02       1.0     1    0.0
# 2    010030000000  Schleswig-Holstein   01    0   03       1.0     1    0.0
# 3    010040000000  Schleswig-Holstein   01    0   04       1.0     1    0.0
# 4    010510000000  Schleswig-Holstein   01    0   51       1.0   116    0.0
# ..            ...                 ...  ...  ...  ...       ...   ...    ...
# 397  160730000000           Thüringen   16    0   73      16.0    26    0.0
# 398  160740000000           Thüringen   16    0   74      16.0    91    0.0
# 399  160750000000           Thüringen   16    0   75      16.0    59    0.0
# 400  160760000000           Thüringen   16    0   76      16.0    42    0.0
# ...

# %%
# df_ade5.to_csv('df_ade5.csv')
df_ade5#.head()
# Out:
#                ARS             BL_name ADE2 ADE3 ADE4  ADE5 ADE2_LAND        \
#                                                                  mean count
# 0     010010000000  Schleswig-Holstein   01    0   01  0000       1.0     1
# 1     010020000000  Schleswig-Holstein   01    0   02  0000       1.0     1
# 2     010030000000  Schleswig-Holstein   01    0   03  0000       1.0     1
# 3     010040000000  Schleswig-Holstein   01    0   04  0000       1.0     1
# 4     010510011000  Schleswig-Holstein   01    0   51  0011       1.0     1
# ...            ...                 ...  ...  ...  ...   ...       ...   ...
# 4591  160775005000           Thüringen   16    0   77  5005      16.0     8
# 4592  160775009000           Thüringen   16    0   77  5009      16.0     6
# 4593  160775050000           Thüringen   16    0   77  5050      16.0     3
# 4594  160775051000           Thüringen   16    0   77  5051      16.0     3
# ...

# %%
df_ade6.to_csv('df_ade6.csv')
df_ade6#.head()
# Out:
#                 ARS             BL_name ADE2 ADE3 ADE4  ADE5 ADE6  \
#
# 0      010010000000  Schleswig-Holstein   01    0   01  0000  000
# 1      010020000000  Schleswig-Holstein   01    0   02  0000  000
# 2      010030000000  Schleswig-Holstein   01    0   03  0000  000
# 3      010040000000  Schleswig-Holstein   01    0   04  0000  000
# 4      010510011011  Schleswig-Holstein   01    0   51  0011  011
# ...             ...                 ...  ...  ...  ...   ...  ...
# 10954  160775051011           Thüringen   16    0   77  5051  011
# 10955  160775051023           Thüringen   16    0   77  5051  023
# 10956  160775051036           Thüringen   16    0   77  5051  036
# 10957  160775052003           Thüringen   16    0   77  5052  003
# 10958  160775052043           Thüringen   16    0   77  5052  043
#
#       EF5_Verbandsbezeichnung                  GEM_TYPE ADE2_LAND  ...  \
#                                                              mean  ...
# ...

# %%
# d_agg = {
#     col_BL_number : ['mean','count'],
#     col_REGBEZ_number : ['mean','count'],
#     col_KREIS_number : ['mean','count'],
#     col_VERBANDGEMEINDE_number : ['mean','count'],
#     col_GEMEINDE_number : ['mean','count'],
#     'EF1_Satzart' : ['count'],
#     'Bevölkerung, insgesamt' : ['sum','median','mean'],
#     'Fläche in ha' : ['sum','median','mean']
# }


# l_by = [
#     col_BL_name, col_BL_number,col_REGBEZ_number,col_KREIS_number, col_VERBANDGEMEINDE_number ,col_GEMEINDE_number,
#     # 'EF3_ARS',
#     'EF5_Verbandsbezeichnung', 'GEM_TYPE'
# ]

# # dict_rename_cols = {'EF1_Satzart', 'Gemeinde'}
# pdf_sum_ade7 = df_60.groupby(l_by).agg(d_agg).round(2)


# print(f'Rows = {df.shape}')
# # df_60_sum = df_60_sum.sort_values(by=['BL_name', 'mean'])

# # if is_cout_sum_added:
# #     totals = df.agg(['count', 'sum'])
# #     df = pd.concat([df, totals])
# #     df.index.names = [col_BL_name]
    
# #     #df.sort_values(by=[col_BL_name],axis=0)#,'BL_nr'])#,'mean'])

# pdf_sum_ade7 = pdf_sum_ade7.rename(columns={
#     col_BL_number: 'ADE2_LAND', 
#     col_REGBEZ_number: 'ADE3_REG_BEZ', 
#     col_KREIS_number: 'ADE4_KREIS',
#     col_VERBANDGEMEINDE_number: 'ADE5_VERB_GEM',
#     col_GEMEINDE_number: 'ADE6_GEMEINDE',
#     'EF1_Satzart': 'Anzahl_GEMEINDE', 
# })
# pdf_sum_ade7
# Out:
# Rows = (16012, 11)
#                                                                                                                 ADE2_LAND  \
#                                                                                                                      mean
# BL_name           BL_nr BEZ_NR KREIS_NR EF4_Verband GEM_NR EF5_Verbandsbezeichnung     GEM_TYPE
# Baden-Württemberg 8     1      11       0           0      Stuttgart, Landeshauptstadt Stadtkreis                     8.0
#                                15       3           3      Böblingen, Stadt            große Kreisstadt               8.0
#                                         28          28     Leonberg, Stadt             große Kreisstadt               8.0
#                                         29          29     Magstadt                    Kreisangehörige Gemeinde       8.0
#                                         41          41     Renningen, Stadt            Stadt                          8.0
# ...

# %%
pdf_sum_de.to_csv('GV100_20241031_clean.csv')

# %% [markdown]
# ### Gemeinden in Deutschland
#
# Deutschland verfügt über insgesamt 11.000 Kommunen, von denen die meisten Gemeinden sind. Nach den aktuellen Zahlen gibt es:
#
# - Rheinland-Pfalz: 2.301 Gemeinden
# - Bayern: 2.056 Gemeinden
# - Schleswig-Holstein: 1.106 Gemeinden
# - Baden-Württemberg: 1.101 Gemeinden
# - Niedersachsen: 941 Gemeinden
# - Mecklenburg-Vorpommern: 726 Gemeinden
# - Thüringen: 631 Gemeinden
# - Hessen: 422 Gemeinden
# - Sachsen: 419 Gemeinden
# - Brandenburg: 416 Gemeinden
# - Nordrhein-Westfalen: 396 Gemeinden
# - Sachsen-Anhalt: 218 Gemeinden
# - Saarland: 52 Gemeinden
# - Bremen: 2 Gemeinden
# - Hamburg: 1 Gemeinde
# - Berlin: 1 Gemeinde

# %% [markdown]
# # REST

# %%
df_gmd_02 = df[df['BL_nr'] == '02']
df_gmd_02
# Out:
#       EF1_Satzart  EF2_Gebietstand   EF3_ARS  EF4_Verband  \
# 1293           10         20241031        02          NaN
# 1294           40         20241031     02000          NaN
# 1295           50         20241031     02000          0.0
# 1296           60         20241031  02000000          0.0
#
#             EF5_Verbandsbezeichnung EF6_Sitz_des_Verbandes  \
# 1293                        Hamburg                Hamburg
# 1294  Hamburg, Freie und Hansestadt                Hamburg
# 1295  Hamburg, Freie und Hansestadt                    NaN
# 1296  Hamburg, Freie und Hansestadt                    NaN
#
#       EF7_Schlüsselfelder                                           EF8_Leer  \
# 1293                  NaN                                                NaN
# 1294                 41.0                                                NaN
# 1295                 50.0                                                NaN
# ...

# %%
df.head(5)
# Out:
#    EF1_Satzart  EF2_Gebietstand   EF3_ARS  EF4_Verband  \
# 0           10         20241031        01          NaN
# 1           40         20241031     01001          NaN
# 2           50         20241031     01001          0.0
# 3           60         20241031  01001000          0.0
# 4           40         20241031     01002          NaN
#
#   EF5_Verbandsbezeichnung EF6_Sitz_des_Verbandes  EF7_Schlüsselfelder  \
# 0      Schleswig-Holstein                   Kiel                  NaN
# 1        Flensburg, Stadt              Flensburg                 41.0
# 2        Flensburg, Stadt                    NaN                 50.0
# 3        Flensburg, Stadt                    NaN                 61.0
# 4  Kiel, Landeshauptstadt                   Kiel                 41.0
#
#                                             EF8_Leer  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
cond_bl = df['BL_nr'] == '03'
cond_satzart_20 = df['EF1_Satzart'] == 20
cond_satzart_30 = df['EF1_Satzart'] == 30
df[cond_bl & cond_satzart]
# Out:
#       EF1_Satzart  EF2_Gebietstand EF3_ARS  EF4_Verband  \
# 1298           20         20241031     031          NaN
# 1568           20         20241031     032          NaN
# 1879           20         20241031     033          NaN
# 2331           20         20241031     034          NaN
#
#                EF5_Verbandsbezeichnung EF6_Sitz_des_Verbandes  \
# 1298  Statistische Region Braunschweig                    NaN
# 1568      Statistische Region Hannover                    NaN
# 1879      Statistische Region Lüneburg                    NaN
# 2331     Statistische Region Weser-Ems                    NaN
#
#       EF7_Schlüsselfelder EF8_Leer  EF9_Frei für landesinterne Angaben BL_nr
# 1298                  NaN      NaN                                 NaN    03
# 1568                  NaN      NaN                                 NaN    03
# 1879                  NaN      NaN                                 NaN    03
# ...

# %%
df[cond_satzart_20]
# Out:
#        EF1_Satzart  EF2_Gebietstand EF3_ARS  EF4_Verband  \
# 1298            20         20241031     031          NaN
# 1568            20         20241031     032          NaN
# 1879            20         20241031     033          NaN
# 2331            20         20241031     034          NaN
# 2747            20         20241031     051          NaN
# 2895            20         20241031     053          NaN
# 3105            20         20241031     055          NaN
# 3270            20         20241031     057          NaN
# 3418            20         20241031     059          NaN
# 3598            20         20241031     064          NaN
# 3985            20         20241031     065          NaN
# 4193            20         20241031     066          NaN
# 4480            20         20241031     071          NaN
# 5671            20         20241031     072          NaN
# 6254            20         20241031     073          NaN
# ...

# %%
df[cond_satzart_20].groupby('BL_nr')['EF5_Verbandsbezeichnung'].count().to_frame()#.agg(['EF5_Verbandsbezeichnung','count'])#count()#.to_frame()#.shape
# Out:
#        EF5_Verbandsbezeichnung
# BL_nr
# 03                           4
# 05                           5
# 06                           3
# 07                           3
# 08                           4
# 09                           7
# 14                           3

# %%
df[cond_satzart_30]
# Out:
#       EF1_Satzart  EF2_Gebietstand EF3_ARS  EF4_Verband  \
# 6992           30         20241031    0811          NaN
# 7261           30         20241031    0812          NaN
# 7428           30         20241031    0813          NaN
# 7507           30         20241031    0821          NaN
# 7604           30         20241031    0822          NaN
# 7734           30         20241031    0823          NaN
# 7843           30         20241031    0831          NaN
# 8024           30         20241031    0832          NaN
# 8127           30         20241031    0833          NaN
# 8261           30         20241031    0841          NaN
# 8366           30         20241031    0842          NaN
# 8495           30         20241031    0843          NaN
#
#               EF5_Verbandsbezeichnung  EF6_Sitz_des_Verbandes  \
# 6992                 Region Stuttgart               Stuttgart
# 7261         Region Heilbronn-Franken               Heilbronn
# ...

# %%
df[cond_satzart_30].groupby('BL_nr')['EF5_Verbandsbezeichnung'].count().to_frame()
# Out:
#        EF5_Verbandsbezeichnung
# BL_nr
# 08                          12

# %% [markdown]
# ## PARSING SATZ60

# %% [markdown]
# # EF8      129-139     11     C NOV11K00     Fläche in ha
# # EF9      140-150     11     C NOV11K00     Bevölkerung, insgesamt
# # EF10     151-161     11     C NOV11K00     Bevölkerung, männlich
# # EF11     162-165      4     C      ALN     Leer
# # EF12     166-175     10                    Neue Postleitzahl
# #  EF12U1  166-170      5     C      ALN      PLZ der Gemeinde (bei mehreren Postleitzahlen - PLZ des Verwaltungssitzes)
# #  EF12U2  171-175      5     C      ALN      Kennzeichnung, ob PLZ eindeutig (leer = Gemeinde hat nur eine PLZ, sonst = Gemeinde hat mehrere PLZ)
# # EF13     176-177      2     C      ALN     LEER
# # EF14     178-181      4     C      ALN     Finanzamtsbezirk
# # EF15     182-185      5                    Gerichtsbarkeit
# #  EF15U1  182-183      2     C      ALN      Oberlandesgerichtsbezirk
# #  EF15U2  184          1     C      ALN      Landgerichtsbezirk
# #  EF15U3  185          1     C      ALN      Amtsgerichtsbezirk
# # EF16     186-190      5     C      ALN     Arbeitsagenturbezirk
# # EF17     191-196      6                    Bundestagswahlkreise
# #  EF17U1  191-193      3     C      ALN      Bundestagswahlkreis
# #  EF17U2  194-196      3     C      ALN      Bundestagswahlkreis
# # EF18     197-200      2     C      ALN    Leer

# %%
# Out:
#     EF1_Satzart  EF2_Gebietstand   EF3_ARS  EF4_Verband  \
# 3            60         20241031  01001000          0.0
# 6            60         20241031  01002000          0.0
# 9            60         20241031  01003000          0.0
# 12           60         20241031  01004000          0.0
# 22           60         20241031  01051001       5175.0
#
#    EF5_Verbandsbezeichnung EF6_Sitz_des_Verbandes  EF7_Schlüsselfelder  \
# 3         Flensburg, Stadt                    NaN                 61.0
# 6   Kiel, Landeshauptstadt                    NaN                 61.0
# 9       Lübeck, Hansestadt                    NaN                 61.0
# 12       Neumünster, Stadt                    NaN                 61.0
# 22              Albersdorf                    NaN                 64.0
#
#                                              EF8_Leer  \
# 3   000000056730000009266700000045905    24937****...
# 6   000000118650000024887300000120699    24103****...
# ...

# %%
# Out:
# C:\Users\gujua\AppData\Local\Temp\ipykernel_11768\3689286373.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[field] = df_60.EF8_Leer.str[pos_start:pos_end]
# C:\Users\gujua\AppData\Local\Temp\ipykernel_11768\3689286373.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_60[field] = df_60[field].fillna(0)
# C:\Users\gujua\AppData\Local\Temp\ipykernel_11768\3689286373.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
l_agg = ['Bevölkerung, insgesamt', 'Bevölkerung, männlich']
df_60group = df_60.groupby('BL_nr')[l_agg].sum()#.to_frame()
df_60group['bev, prozent, mann [%]'] = df_60group['Bevölkerung, männlich']/df_60group['Bevölkerung, insgesamt']
df_60group['bev, prozent, mann [%]'] = df_60group['bev, prozent, mann [%]'].round(3)*100

df_60group# df_60_int = df_60group(l_agg)
# Out:
#        Bevölkerung, insgesamt  Bevölkerung, männlich  bev, prozent, mann [%]
# BL_nr
# 01                     296062                 144628                    48.9
# 02                     191016                  93674                    49.0
# 03                     815768                 402201                    49.3
# 04                      69169                  34198                    49.4
# 05                    1818864                 892902                    49.1
# 06                     641882                 316893                    49.4
# 07                     416373                 205569                    49.4
# 08                    1133444                 562877                    49.7
# 09                    1342580                 665521                    49.6
# 10                      99418                  48877                    49.2
# 11                     378220                 186011                    49.2
# ...

# %%
df_60['Bevölkerung, insgesamt'].sum()
# Out:
# 846693260

# %%
def
